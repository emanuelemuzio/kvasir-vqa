# %%
import sys
sys.path.append('src')

from common.util import get_common_subsequences, ROOT
from kvasirvqa.data import augment_kvasir_vqa
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
from dotenv import load_dotenv 

load_dotenv()
# Out:
# True

# %% [markdown]
# Righe sporche recap:
#
# rigth: 284 (corretto in right)
#
# instrumnets: 3555 (corretto in instruments)
#
# Infine, >20: 38 (corretto in >20mm)

# %%
df = pd.read_csv(f"{ROOT}{os.getenv('KVASIR_VQA_CSV')}")

# %%
df['answer']
# Out:
# 0        ulcerative colitis
# 1                      none
# 2                      none
# 3              not relevant
# 4                       yes
#                 ...
# 58844                   NaN
# 58845                   NaN
# 58846                   NaN
# 58847                   NaN
# 58848                   NaN
# Name: answer, Length: 58849, dtype: object

# %%
df.head()
# Out:
#                source                                           question  \
# 0  Ulcerative Colitis  Are there any abnormalities in the image? Chec...
# 1  Ulcerative Colitis  Are there any anatomical landmarks in the imag...
# 2  Ulcerative Colitis  Are there any instruments in the image? Check ...
# 3  Ulcerative Colitis                      Have all polyps been removed?
# 4  Ulcerative Colitis                    Is this finding easy to detect?
#
#                answer                     img_id
# 0  ulcerative colitis  cla820gl0s3nv071u4fgd7xgq
# 1                none  cla820gl0s3nv071u4fgd7xgq
# 2                none  cla820gl0s3nv071u4fgd7xgq
# 3        not relevant  cla820gl0s3nv071u4fgd7xgq
# 4                 yes  cla820gl0s3nv071u4fgd7xgq

# %%
df.describe()
# Out:
#                     source                       question answer  \
# count                58849                          58849  58798
# unique                   5                             20    501
# top     Ulcerative Colitis  Have all polyps been removed?   none
# freq                 16890                           3945  10520
#
#                            img_id
# count                       58849
# unique                       6500
# top     clb0kvxuz8zw4074yheicg35d
# freq                           18

# %%
df['answer'].isna().sum()
# Out:
# np.int64(51)

# %%
df.dropna(axis=0, inplace=True)

# %%
df.loc[df['answer'] == '>20', 'answer'] = '>20mm'
df['question'] =  df['question'].apply(lambda x : x.replace('instrumnets', 'instruments'))
df['answer'] = df['answer'].apply(lambda x : x.replace('rigth', 'right'))

# %%
df.describe()
# Out:
#                     source                       question answer  \
# count                58798                          58798  58798
# unique                   5                             19    469
# top     Ulcerative Colitis  Have all polyps been removed?   none
# freq                 16884                           3945  10520
#
#                            img_id
# count                       58798
# unique                       6449
# top     clb0kvxuz8zw4074yheicg35d
# freq                           18

# %%
questions = list(sorted(df.question.unique()))

# %%
questions
# Out:
# ['Are there any abnormalities in the image? Check all that are present.',
#  'Are there any anatomical landmarks in the image? Check all that are present.',
#  'Are there any instruments in the image? Check all that are present.',
#  'Does this image contain any finding?',
#  'Have all polyps been removed?',
#  'How many findings are present?',
#  'How many instruments are in the image?',
#  'How many polyps are in the image?',
#  'Is there a green/black box artefact?',
#  'Is there text?',
#  'Is this finding easy to detect?',
#  'What color is the abnormality? If more than one separate with ;',
#  'What color is the anatomical landmark? If more than one separate with ;',
#  'What is the size of the polyp?',
#  'What type of polyp is present?',
#  'What type of procedure is the image taken from?',
#  'Where in the image is the abnormality?',
#  'Where in the image is the anatomical landmark?',
#  'Where in the image is the instrument?']

# %%
df['answer'].str.contains('rigth').sum()
# Out:
# np.int64(0)

# %%
common_subsequences = get_common_subsequences(questions)

common_subsequences
# Out:
# [{'subsequence': 'What', 'freq': 5},
#  {'subsequence': 'Where in the image is the', 'freq': 3},
#  {'subsequence': 'Where in the image is', 'freq': 3},
#  {'subsequence': 'Where in the image', 'freq': 3},
#  {'subsequence': 'Are there any', 'freq': 3},
#  {'subsequence': 'Where in the', 'freq': 3},
#  {'subsequence': 'Are there', 'freq': 3},
#  {'subsequence': 'How many', 'freq': 3},
#  {'subsequence': 'Where in', 'freq': 3},
#  {'subsequence': 'Where', 'freq': 3},
#  {'subsequence': 'Are', 'freq': 3},
#  {'subsequence': 'How', 'freq': 3},
#  {'subsequence': 'Is', 'freq': 3},
#  {'subsequence': 'What color is the', 'freq': 2},
#  {'subsequence': 'What color is', 'freq': 2},
#  {'subsequence': 'What type of', 'freq': 2},
#  {'subsequence': 'What color', 'freq': 2},
#  {'subsequence': 'What type', 'freq': 2},
#  {'subsequence': 'Is there', 'freq': 2}]

# %%
X = list(map(lambda x: x['subsequence'], common_subsequences))

y = list(map(lambda x: x['freq'], common_subsequences))

plt.barh(X, y)
# Out:
# <BarContainer object of 19 artists>

# %%
questions_length = list(map(lambda x: len(x.split(' ')), df.question.tolist()))

max_length = np.max(questions_length)
mean_length = np.mean(questions_length)

print(f"Max question length is: {max_length}")
print(f"Mean question length is: {int(mean_length)}")
# Out:
# Max question length is: 13
# Mean question length is: 7

# %%
df['answer'].value_counts()
# Out:
# answer
# none                                                           10520
# no                                                              8382
# yes                                                             6861
# 0                                                               4538
# 1                                                               4380
#                                                                ...
# center; center-right; lower-right; upper-center; upper-left        1
# white; pink; grey                                                  1
# flesh; blue                                                        1
# lower-center; lower-right; upper-center; upper-left                1
# flesh; blue; red                                                   1
# Name: count, Length: 469, dtype: int64

# %%
all_answers = df['answer'].value_counts()
threshold = 8
answer_aug = [k for k, v in all_answers.items() if v < 8]

# %%
print(f"Answers for augmentation: {len(answer_aug)}")
# Out:
# Answers for augmentation: 326

# %%
aug_df = None
new_df = None

# %%
if len(os.listdir(os.getenv('KVASIR_VQA_DATA_AUG'))) == 0:
    aug_df = augment_kvasir_vqa(df, answer_aug, threshold)
    new_df = pd.concat([df, aug_df], axis=0)
    new_df.to_csv(f"{ROOT}/{os.getenv('KVASIR_VQA_CSV_AUG')}", index=False)
else:
    new_df = pd.read_csv(os.getenv('KVASIR_VQA_CSV_AUG'))

# %%
new_df['answer'].value_counts()
# Out:
# answer
# none                                                           10520
# no                                                              8382
# yes                                                             6861
# 0                                                               4538
# 1                                                               4380
#                                                                ...
# green; white                                                       8
# white; purple                                                      8
# lower-center; lower-right; upper-center; upper-right               8
# center; lower-center; lower-right; upper-center; upper-left        8
# biopsy forceps; metal clip                                         8
# Name: count, Length: 469, dtype: int64

# %%
print(f"{len(new_df) - len(df)} new rows generated")
# Out:
# 1940 new rows generated

# %%
label_count = {}
all_labels = []
for answer in df['answer'].value_counts().keys():
        all_labels.extend([answ.strip() for answ in answer.split(';')])

# %%
all_labels
# Out:
# ['none',
#  'no',
#  'yes',
#  '0',
#  '1',
#  'not relevant',
#  'colonoscopy',
#  'center',
#  'center-left',
#  'center-right',
#  'lower-center',
#  'lower-left',
#  'lower-right',
#  'upper-center',
#  'upper-left',
#  'upper-right',
#  'pink',
#  'red',
#  'white',
#  'polyp',
#  '2',
#  'gastroscopy',
#  'ulcerative colitis',
#  'oesophagitis',
#  'z-line',
#  'tube',
#  'paris ip',
#  'paris is',
#  'pink',
#  'red',
#  '11-20mm',
#  '5-10mm',
#  'paris iia',
#  '>20mm',
#  'pink',
#  'center',
#  'center-left',
#  'upper-center',
#  'upper-left',
#  'center',
#  'center-left',
#  'center-right',
#  'lower-center',
#  'lower-right',
#  'upper-center',
#  'upper-left',
#  'upper-right',
#  '<5mm',
#  'center',
#  'upper-center',
#  'center',
#  'center-right',
#  'lower-center',
#  'lower-right',
#  'red',
#  'pink',
#  'pink',
#  'white',
#  'cecum',
#  'center',
#  'center-right',
#  'lower-center',
#  'lower-right',
#  'upper-center',
#  'upper-right',
#  'lower-center',
#  'lower-right',
#  'center',
#  'center-right',
#  'upper-center',
#  'upper-right',
#  'center',
#  'biopsy forceps',
#  'center',
#  'lower-center',
#  'center',
#  'center-left',
#  'lower-center',
#  'lower-left',
#  'upper-center',
#  'upper-left',
#  'center-left',
#  'upper-left',
#  'center',
#  'center-left',
#  'lower-center',
#  'lower-left',
#  'center',
#  'lower-center',
#  'lower-right',
#  'center',
#  'lower-center',
#  'upper-center',
#  'center',
#  'center-left',
#  'lower-center',
#  'upper-center',
#  'upper-left',
#  'pink',
#  'red',
#  'yellow',
#  'pink',
#  'red',
#  'white',
#  'yellow',
#  '3',
#  'center',
#  'center-left',
#  'upper-left',
#  'red',
#  'pink',
#  'yellow',
#  'lower-center',
#  'upper-center',
#  'pink',
#  'yellow',
#  'white',
#  'center',
#  'center-right',
#  'upper-center',
#  'upper-left',
#  'red',
#  'pink',
#  'white',
#  'center',
#  'upper-center',
#  'upper-left',
#  'pink',
#  'yellow',
#  'center',
#  'center-left',
#  'lower-center',
#  'lower-left',
#  'upper-left',
#  'center-right',
#  'upper-right',
#  'polyp snare',
#  'tube',
#  'center',
#  'center-left',
#  'center-right',
#  'lower-center',
#  'lower-left',
#  'lower-right',
#  'upper-center',
#  'upper-left',
#  'polyp snare',
#  'flesh',
#  'red',
#  'center',
#  'center-right',
#  'lower-center',
#  'lower-right',
#  'upper-right',
#  'pink',
#  'red',
#  'yellow',
#  'white',
#  'center',
#  'center-left',
#  'center-right',
#  'lower-center',
#  'upper-center',
#  'center',
#  'center-right',
#  'upper-right',
#  'upper-center',
#  'upper-right',
#  'paris ip',
#  'paris is',
#  'lower-right',
#  'center-right',
#  'lower-right',
#  'pink',
#  'white',
#  'yellow',
#  'center',
#  'center-left',
#  'center-right',
#  'upper-center',
#  'upper-left',
#  'upper-right',
#  'center',
#  'center-right',
#  'lower-center',
#  'upper-center',
#  'upper-right',
#  'center',
#  'center-left',
#  'center-left',
#  'lower-left',
#  'upper-left',
#  'paris iia',
#  'paris is',
#  'center-right',
#  'lower-right',
#  'upper-right',
#  'center',
#  'center-right',
#  'lower-center',
#  'lower-right',
#  'upper-center',
#  'white',
#  'flesh',
#  'center-left',
#  'center-right',
#  'lower-center',
#  'lower-left',
#  'lower-right',
#  'upper-center',
#  'upper-left',
#  'upper-right',
#  'center',
#  'upper-center',
#  'upper-right',
#  'metal clip',
#  'red',
#  '5-10mm',
#  '<5mm',
#  'center',
#  'center-left',
#  'center-right',
#  'lower-center',
#  'lower-left',
#  'lower-right',
#  'red',
#  'flesh',
#  'center',
#  'center-right',
#  'lower-center',
#  '4',
#  'flesh',
#  'white',
#  'pink',
#  'red',
#  'white',
#  'brown',
#  'lower-center',
#  'lower-left',
#  'flesh',
#  'red',
#  'flesh',
#  'white',
#  'center',
#  'center-right',
#  'lower-center',
#  'upper-center',
#  'center',
#  'center-left',
#  'center-right',
#  'lower-center',
#  'lower-left',
#  'upper-center',
#  'upper-left',
#  'upper-right',
#  'barretts',
#  'oesophagitis',
#  'center',
#  'center-left',
#  'upper-center',
#  'center-right',
#  'upper-left',
#  'center',
#  'center-left',
#  'center-right',
#  'lower-center',
#  'upper-center',
#  'upper-left',
#  'upper-right',
#  'center',
#  'center-left',
#  'center-right',
#  'lower-center',
#  'lower-left',
#  'lower-right',
#  'upper-center',
#  'upper-right',
#  'red',
#  'pink',
#  'orange',
#  'pink',
#  'red',
#  'brown',
#  'pink',
#  'red',
#  'orange',
#  'center',
#  'center-right',
#  'upper-center',
#  'center',
#  'center-right',
#  'lower-right',
#  'upper-center',
#  'upper-right',
#  'center',
#  'center-left',
#  'lower-center',
#  'lower-left',
#  'upper-center',
#  'pink',
#  'white',
#  'red',
#  'pink',
#  'red',
#  'white',
#  'grey',
#  'center',
#  'center-left',
#  'center-right',
#  'lower-center',
#  'lower-right',
#  'upper-center',
#  'upper-left',
#  'red',
#  'pink',
#  'brown',
#  'center',
#  'center-left',
#  'center-right',
#  'lower-center',
#  'upper-center',
#  'upper-left',
#  'center-right',
#  'upper-center',
#  'upper-right',
#  'oesophagitis',
#  'short-segment barretts',
#  'center',
#  'center-right',
#  'lower-right',
#  'center',
#  'center-left',
#  'center-right',
#  'lower-center',
#  'lower-right',
#  'upper-center',
#  'upper-right',
#  'center-left',
#  'upper-center',
#  'upper-left',
#  'center',
#  'center-right',
#  'lower-right',
#  'upper-right',
#  'center',
#  'center-left',
#  'lower-center',
#  'upper-center',
#  'red',
#  'white',
#  'flesh',
#  'upper-right',
#  'center',
#  'center-left',
#  'lower-center',
#  'upper-left',
#  'center-left',
#  'lower-center',
#  'lower-left',
#  'upper-left',
#  'center',
#  'center-right',
#  'upper-center',
#  'upper-left',
#  'upper-right',
#  'flesh',
#  'white',
#  'red',
#  'center',
#  'center-left',
#  'center-right',
#  'lower-center',
#  'lower-left',
#  'upper-center',
#  'upper-left',
#  'center',
#  'center-left',
#  'lower-center',
#  'center',
#  'center-left',
#  'center-right',
#  'lower-center',
#  'lower-left',
#  'lower-right',
#  'upper-center',
#  'red',
#  'yellow',
#  'pink',
#  'center-right',
#  'lower-center',
#  'lower-right',
#  'flesh',
#  'red',
#  'white',
#  'center-left',
#  'lower-left',
#  'center',
#  'center-right',
#  'lower-center',
#  'lower-left',
#  'lower-right',
#  'upper-center',
#  'upper-left',
#  'upper-right',
#  'center',
#  'center-left',
#  'lower-left',
#  'biopsy forceps',
#  'tube',
#  'center',
#  'lower-center',
#  'lower-left',
#  'white',
#  'red',
#  'flesh',
#  '11-20mm',
#  '>20mm',
#  '5',
#  'center',
#  'center-left',
#  'center-right',
#  'upper-center',
#  'oesophagitis',
#  'polyp',
#  'center-left',
#  'center',
#  'center-right',
#  'lower-center',
#  'lower-right',
#  'upper-center',
#  'upper-left',
#  'upper-right',
#  'red',
#  'white',
#  'pink',
#  'white',
#  'flesh',
#  'red',
#  'center',
#  'center-left',
#  'center-right',
#  'lower-center',
#  'lower-right',
#  'upper-center',
#  'center',
#  'center-left',
#  'center-right',
#  'upper-center',
#  'upper-left',
#  'center',
#  'center-left',
#  'center-right',
#  'lower-center',
#  'upper-center',
#  'upper-right',
#  '11-20mm',
#  '5-10mm',
#  'lower-left',
#  'center',
#  'center-left',
#  'center-right',
#  'lower-center',
#  'lower-left',
#  'upper-center',
#  'center',
#  'center-left',
#  'lower-center',
#  'lower-left',
#  'lower-right',
#  'upper-center',
#  'upper-left',
#  'center',
#  'upper-center',
#  'upper-left',
#  'upper-right',
#  'center',
#  'center-left',
#  'center-right',
#  'upper-center',
#  'upper-right',
#  'ileum',
#  'metal clip',
#  'tube',
#  'center',
#  'center-left',
#  'lower-left',
#  'upper-center',
#  'upper-left',
#  '11-20mm',
#  '<5mm',
#  'center',
#  'center-left',
#  'center-right',
#  'lower-center',
#  'lower-left',
#  'upper-center',
#  'upper-right',
#  'pink',
#  'yellow',
#  'red',
#  'center',
#  'lower-center',
#  'upper-center',
#  'upper-left',
#  'pink',
#  'white',
#  'brown',
#  'red',
#  'brown',
#  'pink',
#  'pink',
#  'red',
#  'brown',
#  'white',
#  'pink',
#  'brown',
#  'black',
#  'red',
#  'white',
#  'yellow',
#  'polyp',
#  'ulcerative colitis',
#  'center',
#  'center-right',
#  'upper-center',
#  'upper-left',
#  'center-right',
#  'lower-center',
#  'lower-right',
#  'upper-right',
#  'pink',
#  'red',
#  'yellow',
#  'black',
#  'center',
#  'center-left',
#  'lower-center',
#  'lower-left',
#  'lower-right',
#  'center',
#  'center-right',
#  'lower-center',
#  'lower-left',
#  'lower-right',
#  'white',
#  'pink',
#  'red',
#  'center',
#  'lower-center',
#  'lower-left',
#  'upper-center',
#  'black',
#  'white',
#  'pink',
#  'red',
#  'yellow',
#  'orange',
#  'center',
#  'center-left',
#  'center-right',
#  'lower-center',
#  'lower-right',
#  'center',
#  'center-left',
#  'lower-center',
#  'lower-right',
#  'upper-center',
#  'upper-left',
#  'white',
#  'red',
#  'pink',
#  'center',
#  'center-right',
#  'lower-center',
#  'upper-right',
#  'pink',
#  'grey',
#  'white',
#  'center-left',
#  'lower-center',
#  'lower-left',
#  'pink',
#  'white',
#  'grey',
#  'center-left',
#  'lower-center',
#  'upper-center',
#  'center',
#  'center-left',
#  'center-right',
#  'lower-right',
#  'upper-center',
#  'upper-left',
#  'center-right',
#  'lower-center',
#  'lower-right',
#  'upper-center',
#  'upper-right',
#  'pylorus',
#  'center',
#  'center-left',
#  'center-right',
#  'lower-center',
#  'lower-left',
#  'center',
#  'upper-right',
#  '5-10mm',
#  '>20mm',
#  'yellow',
#  'white',
#  'pink',
#  'red',
#  'center',
#  'lower-left',
#  'upper-center',
#  'center',
#  'center-left',
#  'center-right',
#  'lower-center',
#  'lower-left',
#  'lower-right',
#  'upper-right',
#  'center-right',
#  'lower-center',
#  'lower-left',
#  'lower-right',
#  'upper-center',
#  'upper-left',
#  'upper-right',
#  '11-20mm',
#  '5-10mm',
#  '>20mm',
#  'center',
#  'center-right',
#  'lower-center',
#  'lower-right',
#  'upper-center',
#  'upper-left',
#  'center',
#  'center-left',
#  'center-right',
#  'lower-left',
#  'lower-right',
#  'upper-center',
#  'upper-left',
#  'upper-right',
#  'center',
#  'center-right',
#  'lower-center',
#  'lower-left',
#  'lower-right',
#  'upper-center',
#  'upper-right',
#  'center',
#  'center-left',
#  'lower-center',
#  'lower-left',
#  'lower-right',
#  'upper-center',
#  'upper-left',
#  'upper-right',
#  'white',
#  'red',
#  'center',
#  'center-left',
#  'center-right',
#  'lower-center',
#  '11-20mm',
#  '5-10mm',
#  '<5mm',
#  'pink',
#  'red',
#  'white',
#  'black',
#  'red',
#  'pink',
#  'brown',
#  'white',
#  'center',
#  'center-left',
#  'lower-center',
#  'lower-right',
#  'red',
#  'pink',
#  'yellow',
#  'brown',
#  'red',
#  'pink',
#  'white',
#  'brown',
#  'center',
#  'upper-left',
#  'center',
#  'center-left',
#  'center-right',
#  'center',
#  'lower-center',
#  'lower-left',
#  'lower-right',
#  'center-left',
#  'center-right',
#  'lower-center',
#  'lower-right',
#  'upper-center',
#  'upper-left',
#  'upper-right',
#  'pink',
#  'white',
#  'yellow',
#  'red',
#  'pink',
#  'red',
#  'grey',
#  'center',
#  'lower-center',
#  'upper-center',
#  'upper-right',
#  'center',
#  'center-left',
#  'lower-center',
#  'lower-left',
#  'upper-center',
#  'upper-left',
#  'upper-right',
#  'center-right',
#  'lower-center',
#  'center',
#  'lower-left',
#  'upper-center',
#  'upper-left',
#  'white',
#  'pink',
#  'center-left',
#  'center-right',
#  'lower-center',
#  'lower-left',
#  'upper-center',
#  'upper-left',
#  'upper-right',
#  'yellow',
#  'flesh',
#  'red',
#  'barretts',
#  'center',
#  'center-left',
#  'upper-center',
#  'upper-left',
#  'upper-right',
#  'pink',
#  'yellow',
#  'orange',
#  'grey',
#  'white',
#  'pink',
#  'yellow',
#  'red',
#  'white',
#  'center',
#  'center-right',
#  'lower-center',
#  'lower-left',
#  'center',
#  'center-left',
#  'center-right',
#  'lower-left',
#  'upper-center',
#  'upper-left',
#  'upper-right',
#  'white',
#  'flesh',
#  'yellow',
#  'flesh',
#  'white',
#  'yellow',
#  'capsule endoscopy',
#  '6',
#  'pink',
#  'yellow',
#  'green',
#  'white',
#  'flesh',
#  'red',
#  'orange',
#  'center',
#  'center-left',
#  'lower-left',
#  'upper-left',
#  'center-right',
#  'lower-right',
#  'upper-center',
#  'upper-right',
#  'injection needle',
#  'center',
#  'center-left',
#  'lower-center',
#  'lower-left',
#  'upper-center',
#  'upper-right',
#  'center',
#  'center-right',
#  'lower-center',
#  'upper-center',
#  'upper-left',
#  'upper-right',
#  'center',
#  'lower-center',
#  'lower-left',
#  'upper-center',
#  'upper-left',
#  'pink',
#  'purple',
#  'white',
#  'pink',
#  'white',
#  'red',
#  'yellow',
#  'flesh',
#  'pink',
#  'yellow',
#  'flesh',
#  'pink',
#  'lower-right',
#  'upper-right',
#  'flesh',
#  'yellow',
#  'white',
#  'center',
#  'lower-right',
#  'pink',
#  'yellow',
#  'brown',
#  'center',
#  'center-left',
#  'lower-center',
#  'lower-left',
#  'upper-right',
#  'center',
#  'center-right',
#  'upper-left',
#  'upper-right',
#  'orange',
#  'flesh',
#  'white',
#  'flesh',
#  'pink',
#  'red',
#  'center-left',
#  'lower-center',
#  'upper-left',
#  'center',
#  'center-left',
#  'lower-center',
#  'upper-center',
#  'upper-left',
#  'upper-right',
#  'center',
#  'center-left',
#  'lower-left',
#  'upper-center',
#  'yellow',
#  'pink',
#  'yellow',
#  'pink',
#  'brown',
#  'red',
#  'pink',
#  'brown',
#  'yellow',
#  'pink',
#  'grey',
#  '16',
#  'white',
#  'red',
#  'yellow',
#  'pink',
#  'red',
#  'white',
#  'purple',
#  'red',
#  'pink',
#  'grey',
#  'orange',
#  'flesh',
#  'red',
#  'yellow',
#  'white',
#  'flesh',
#  'center-left',
#  'center-right',
#  'lower-left',
#  'lower-right',
#  'upper-center',
#  'upper-left',
#  'upper-right',
#  'pink',
#  'red',
#  'grey',
#  'white',
#  'white',
#  'pink',
#  'yellow',
#  'red',
#  'pink',
#  'yellow',
#  'white',
#  'pink',
#  'red',
#  'brown',
#  'yellow',
#  'upper-center',
#  'upper-left',
#  'upper-right',
#  'pink',
#  'red',
#  'orange',
#  'brown',
#  'center',
#  'center-left',
#  'lower-center',
#  'lower-left',
#  'lower-right',
#  'upper-left',
#  'white',
#  'yellow',
#  'flesh',
#  'yellow',
#  'red',
#  'flesh',
#  'yellow',
#  'upper-left',
#  'upper-right',
#  'center-left',
#  'lower-center',
#  'center',
#  'center-left',
#  'lower-center',
#  'lower-right',
#  'upper-left',
#  'pink',
#  'red',
#  'yellow',
#  'white',
#  'grey',
#  'biopsy forceps',
#  'metal clip',
#  'white',
#  'pink',
#  'brown',
#  'center',
#  'center-left',
#  'center-right',
#  'lower-center',
#  'lower-left',
#  'lower-right',
#  'upper-left',
#  'upper-right',
#  'center',
#  'center-left',
#  'lower-center',
#  'lower-right',
#  'upper-center',
#  'upper-right',
#  'center',
#  'center-right',
#  'lower-center',
#  'lower-left',
#  'upper-center',
#  'upper-left',
#  'upper-right',
#  'center',
#  'lower-left',
#  'lower-right',
#  'upper-center',
#  'upper-left',
#  'center-right',
#  'lower-center',
#  'upper-center',
#  'upper-left',
#  'upper-right',
#  'center-left',
#  'center-right',
#  'upper-center',
#  'pink',
#  'red',
#  'yellow',
#  'green',
#  'white',
#  'grey',
#  'center',
#  'center-left',
#  'lower-right',
#  'upper-center',
#  'upper-left',
#  'upper-right',
#  'center',
#  'lower-center',
#  'lower-right',
#  'upper-center',
#  'center-left',
#  'center-right',
#  ...]

# %%
for label in all_labels:
    label_count[label] = all_labels.count(label)

# %%
len(label_count.keys())
# Out:
# 58

# %%
import matplotlib.pyplot as plt

label_count = dict(sorted(label_count.items(), key=lambda item: item[1], reverse=True))
num_elements = len(label_count.keys())
elements = label_count.keys()
frequencies = label_count.values()

plt.figure(figsize=(15, 8))
plt.bar(elements, frequencies, width=0.8, edgecolor='black', alpha=0.7)

plt.xlabel("Risposte", fontsize=12)
plt.ylabel("Frequenza", fontsize=12)
plt.title("Distribuzione delle Frequenze", fontsize=16)
plt.xticks(rotation=90, fontsize=8)   

plt.tight_layout()
plt.show()

# %%
df.to_csv(os.getenv('KVASIR_VQA_CSV_CLEAN'), index=False)

# %%
import json

if not os.path.exists(os.getenv("KVASIR_VQA_VOCABULARY_MULTILABEL")):

    multilabel_df = pd.read_csv(os.getenv('KVASIR_VQA_CSV_CLEAN'))

    labels_subset = []

    multilabel_df['answer'].apply(lambda x : labels_subset.extend(list(map(lambda y : y.strip(), x.split(';')))))

    labels_subset = list(sorted(set(labels_subset), reverse=True))

    multilabel_dict = { x : i for (i, x) in zip(range(len(labels_subset)), labels_subset)}

    out_file = open(os.getenv("KVASIR_VQA_VOCABULARY_MULTILABEL"), "w")

    json.dump(multilabel_dict, out_file, indent = 6)

    out_file.close()
    
    multilabel_columns = ['source', 'question', 'img_id']
    multilabel_columns.extend(labels_subset)
    
    multilabel_data = []

    for i in range(len(df)):
        row = df.iloc[i]
        answers = list(map(lambda x : x.strip(), row['answer'].split(';')))
        multilabel_answers = [0] * len(labels_subset)
        for answ in answers:
            multilabel_answers[labels_subset.index(answ)] = 1
        multilabel_row = [row['source'], row['question'], row['img_id']]
        multilabel_row.extend(multilabel_answers)
        multilabel_data.append(multilabel_row)
        
    pd.DataFrame(data=multilabel_data, columns=multilabel_columns).to_csv(os.getenv('METADATA_MULTILABEL_CSV'), index=False)

# %%
if not os.path.exists(os.getenv('QUESTIONS_MAP')):
    
    questions_map = {}

    for q in questions:
        filt = df[df['question'] == q]
        xss = filt['answer'].map(lambda x : x.split(';')).to_list()
        o = list(set([x.strip() for xs in xss for x in xs]))
        questions_map[q] = o
         
        out_file = open(os.getenv("QUESTIONS_MAP"), "w")

        json.dump(questions_map, out_file, indent = 6)

        out_file.close()

# %%
questions
# Out:
# ['Are there any abnormalities in the image? Check all that are present.',
#  'Are there any anatomical landmarks in the image? Check all that are present.',
#  'Are there any instruments in the image? Check all that are present.',
#  'Does this image contain any finding?',
#  'Have all polyps been removed?',
#  'How many findings are present?',
#  'How many instruments are in the image?',
#  'How many polyps are in the image?',
#  'Is there a green/black box artefact?',
#  'Is there text?',
#  'Is this finding easy to detect?',
#  'What color is the abnormality? If more than one separate with ;',
#  'What color is the anatomical landmark? If more than one separate with ;',
#  'What is the size of the polyp?',
#  'What type of polyp is present?',
#  'What type of procedure is the image taken from?',
#  'Where in the image is the abnormality?',
#  'Where in the image is the anatomical landmark?',
#  'Where in the image is the instrument?']

# %%
from nltk.tokenize import RegexpTokenizer

tokenizer = RegexpTokenizer(r'\w+')

# %%
from transformers import AutoTokenizer, ViltProcessor
from common.util import flatten

vilt_processor = ViltProcessor.from_pretrained("dandelin/vilt-b32-mlm")
custom_tokenizer = AutoTokenizer.from_pretrained("emilyalsentzer/Bio_ClinicalBERT")
# Out:
# c:\Users\emanu\Desktop\Tesi\kvasir-vqa\venv\Lib\site-packages\transformers\tokenization_utils_base.py:1617: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be deprecated in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(

# %%
clean_df = pd.read_csv(os.getenv('KVASIR_VQA_CSV_CLEAN'))
kvasir_vqa_tokens = list(set(flatten(clean_df['question'].map(lambda x : tokenizer.tokenize(x.lower())) + clean_df['answer'].map(lambda x : tokenizer.tokenize(x.lower())))))

# %%
vilt_new_tokens = kvasir_vqa_tokens - vilt_processor.tokenizer.vocab.keys() 
print("N. of vilt new tokens: ", len(vilt_new_tokens))
print(' / '.join(vilt_new_tokens))
# Out:
# N. of vilt new tokens:  22
# gastroscopy / artefact / snare / barretts / colonoscopy / forceps / endoscopy / 20mm / polyp / ulcerative / pylorus / iia / ileum / 10mm / hemorrhoids / abnormality / biopsy / oesophagitis / colitis / 5mm / polyps / cecum

# %%
custom_new_tokens = kvasir_vqa_tokens - custom_tokenizer.vocab.keys() 
print("N. of custom new tokens: ", len(custom_new_tokens))
print(' / '.join(custom_new_tokens))
# Out:
# N. of custom new tokens:  26
# ip / gastroscopy / artefact / snare / barretts / paris / colonoscopy / forceps / endoscopy / abnormalities / 20mm / polyp / anatomical / ulcerative / pylorus / iia / ileum / 10mm / hemorrhoids / abnormality / biopsy / oesophagitis / colitis / 5mm / polyps / cecum
